# %%
import pandas as pd
import json
import os
import math
import numpy as np
import librosa, librosa.display

# %% [markdown]
# ##**READ DATASET**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/GTZAN dataset/Data/features_3_sec.csv")
df.head(10)
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# 5  blues.00000.5.wav   66149          0.376670         0.089702  0.132618
# 6  blues.00000.6.wav   66149          0.379909         0.088827  0.130335
# 7  blues.00000.7.wav   66149          0.331880         0.092119  0.140600
# 8  blues.00000.8.wav   66149          0.347877         0.094209  0.133130
# 9  blues.00000.9.wav   66149          0.358061         0.082957  0.115312
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
# 5  0.003583             1994.915219          211700.619569
# 6  0.003166             1962.150096          177443.070045
# 7  0.002546             1701.890924           35678.130616
# 8  0.002538             1746.473502          138073.931244
# 9  0.001846             1763.948942           61493.423121
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
# 5              2152.767854            74263.873102  ...   31.448069
# 6              2146.503479            98020.541422  ...   33.954071
# 7              1979.387612            36670.725886  ...   38.456211
# 8              1887.619723           117069.920049  ...   44.311455
# 9              1874.195710            51944.921435  ...   43.967834
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
# 5    -3.448373   34.284130    -0.416165   40.791092    -3.649625   32.457901
# 6    -2.068194   25.623655     1.428141   47.957699    -3.267124   39.382240
# 7    -3.637886   24.530296    -0.105148   26.716150    -2.016985   23.150423
# 8    -4.370029   29.873167     2.114592   33.843155    -2.264663   80.812393
# 9    -3.448304   48.671944     0.099792   41.839546    -7.677177   96.253654
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
# 5     3.025218   28.892687  blues
# 6     3.276939   25.999132  blues
# 7     0.210787   42.512966  blues
# 8     3.758598   97.618835  blues
# 9     0.791776   40.416420  blues
#
# [10 rows x 60 columns]

# %% [markdown]
# ##**ABOUT DATASET**

# %%
print("Dataset has",df.shape)
print("Count of Positive and Negative samples")
df.label.value_counts().reset_index()
# Out:
# Dataset has (9990, 60)
# Count of Positive and Negative samples
#        label  count
# 0      blues   1000
# 1       jazz   1000
# 2      metal   1000
# 3        pop   1000
# 4     reggae   1000
# 5      disco    999
# 6  classical    998
# 7     hiphop    998
# 8       rock    998
# 9    country    997

# %%
print("Columns with NA values are",list(df.columns[df.isnull().any()]))
# Out:
# Columns with NA values are []

# %%
df.dtypes
# Out:
# filename                    object
# length                       int64
# chroma_stft_mean           float64
# chroma_stft_var            float64
# rms_mean                   float64
# rms_var                    float64
# spectral_centroid_mean     float64
# spectral_centroid_var      float64
# spectral_bandwidth_mean    float64
# spectral_bandwidth_var     float64
# rolloff_mean               float64
# rolloff_var                float64
# zero_crossing_rate_mean    float64
# zero_crossing_rate_var     float64
# harmony_mean               float64
# harmony_var                float64
# perceptr_mean              float64
# perceptr_var               float64
# tempo                      float64
# mfcc1_mean                 float64
# mfcc1_var                  float64
# mfcc2_mean                 float64
# mfcc2_var                  float64
# mfcc3_mean                 float64
# mfcc3_var                  float64
# mfcc4_mean                 float64
# mfcc4_var                  float64
# mfcc5_mean                 float64
# mfcc5_var                  float64
# mfcc6_mean                 float64
# mfcc6_var                  float64
# mfcc7_mean                 float64
# mfcc7_var                  float64
# mfcc8_mean                 float64
# mfcc8_var                  float64
# mfcc9_mean                 float64
# mfcc9_var                  float64
# mfcc10_mean                float64
# mfcc10_var                 float64
# mfcc11_mean                float64
# mfcc11_var                 float64
# mfcc12_mean                float64
# mfcc12_var                 float64
# mfcc13_mean                float64
# mfcc13_var                 float64
# mfcc14_mean                float64
# mfcc14_var                 float64
# mfcc15_mean                float64
# mfcc15_var                 float64
# mfcc16_mean                float64
# mfcc16_var                 float64
# mfcc17_mean                float64
# mfcc17_var                 float64
# mfcc18_mean                float64
# mfcc18_var                 float64
# mfcc19_mean                float64
# mfcc19_var                 float64
# mfcc20_mean                float64
# mfcc20_var                 float64
# label                       object
# dtype: object

# %%
df = df.drop(labels="filename", axis=1)

# %%
df.head(10)
# Out:
#    length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0   66149          0.335406         0.091048  0.130405  0.003521
# 1   66149          0.343065         0.086147  0.112699  0.001450
# 2   66149          0.346815         0.092243  0.132003  0.004620
# 3   66149          0.363639         0.086856  0.132565  0.002448
# 4   66149          0.335579         0.088129  0.143289  0.001701
# 5   66149          0.376670         0.089702  0.132618  0.003583
# 6   66149          0.379909         0.088827  0.130335  0.003166
# 7   66149          0.331880         0.092119  0.140600  0.002546
# 8   66149          0.347877         0.094209  0.133130  0.002538
# 9   66149          0.358061         0.082957  0.115312  0.001846
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1773.065032          167541.630869              1972.744388
# 1             1816.693777           90525.690866              2010.051501
# 2             1788.539719          111407.437613              2084.565132
# 3             1655.289045          111952.284517              1960.039988
# 4             1630.656199           79667.267654              1948.503884
# 5             1994.915219          211700.619569              2152.767854
# 6             1962.150096          177443.070045              2146.503479
# 7             1701.890924           35678.130616              1979.387612
# 8             1746.473502          138073.931244              1887.619723
# 9             1763.948942           61493.423121              1874.195710
#
#    spectral_bandwidth_var  rolloff_mean  ...  mfcc16_var  mfcc17_mean  \
# 0           117335.771563   3714.560359  ...   39.687145    -3.241280
# 1            65671.875673   3869.682242  ...   64.748276    -6.055294
# 2            75124.921716   3997.639160  ...   67.336563    -1.768610
# 3            82913.639269   3568.300218  ...   47.739452    -3.841155
# 4            60204.020268   3469.992864  ...   30.336359     0.664582
# 5            74263.873102   4371.985614  ...   31.448069    -3.448373
# 6            98020.541422   4325.026668  ...   33.954071    -2.068194
# 7            36670.725886   3625.280386  ...   38.456211    -3.637886
# 8           117069.920049   3586.934721  ...   44.311455    -4.370029
# 9            51944.921435   3505.522649  ...   43.967834    -3.448304
#
#    mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  \
# 0   36.488243     0.722209   38.099152    -5.050335   33.618073    -0.243027
# 1   40.677654     0.159015   51.264091    -2.837699   97.030830     5.784063
# 2   28.348579     2.378768   45.717648    -1.938424   53.050835     2.517375
# 3   28.337118     1.218588   34.770935    -3.580352   50.836224     3.630866
# 4   45.880913     1.689446   51.363583    -3.392489   26.738789     0.536961
# 5   34.284130    -0.416165   40.791092    -3.649625   32.457901     3.025218
# 6   25.623655     1.428141   47.957699    -3.267124   39.382240     3.276939
# 7   24.530296    -0.105148   26.716150    -2.016985   23.150423     0.210787
# 8   29.873167     2.114592   33.843155    -2.264663   80.812393     3.758598
# 9   48.671944     0.099792   41.839546    -7.677177   96.253654     0.791776
#
#    mfcc20_var  label
# 0   43.771767  blues
# 1   59.943081  blues
# 2   33.105122  blues
# 3   32.023678  blues
# 4   29.146694  blues
# 5   28.892687  blues
# 6   25.999132  blues
# 7   42.512966  blues
# 8   97.618835  blues
# 9   40.416420  blues
#
# [10 rows x 59 columns]

# %% [markdown]
# ##**DATA VISUALIZATION**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Computing the Correlation Matrix
spike_cols = [col for col in df.columns if 'mean' in col]
corr = df[spike_cols].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool_))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Generate a custom diverging colormap
cmap = sns.diverging_palette(0, 25, as_cmap=True, s = 90, l = 45, n = 5)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Heatmap (for the MEAN variables)', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);
plt.savefig("Corr_Heatmap.png")

# %%
x = df[["label", "tempo"]]

fig, ax = plt.subplots(figsize=(16, 8));
sns.boxplot(x = "label", y = "tempo", data = x, palette = 'husl');

plt.title('BPM Boxplot for Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("BPM", fontsize = 15)
plt.savefig("BPM_Boxplot.png")
# Out:
# <ipython-input-12-dc30ed650620>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = "label", y = "tempo", data = x, palette = 'husl');

# %%
import sklearn.preprocessing as skp
data = df.iloc[0:, 1:]
y = data['label']
X = data.loc[:, data.columns != 'label']

# normalize
cols = X.columns
min_max_scaler = skp.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(np_scaled, columns = cols)

# Top 2 pca components
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2'])

# concatenate with target label
finalDf = pd.concat([principalDf, y], axis = 1)

plt.figure(figsize = (16, 9))
sns.scatterplot(x = "pc1", y = "pc2", data = finalDf, hue = "label", alpha = 0.7, s = 100);

plt.title('PCA on Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Principal Component 1", fontsize = 15)
plt.ylabel("Principal Component 2", fontsize = 15)
plt.savefig("PCA_Scattert.png")

# %% [markdown]
# ##**BUILDING MODEL**

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

import matplotlib.pyplot as plt
import random

import librosa
import math

# %%
DATASET_PATH = "/content/drive/MyDrive/GTZAN dataset/Data/genres_original"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file

                file_path = os.path.join(dirpath, f)

                if file_path != '/content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00054.wav':

                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)


                    # process all segments of audio file
                    for d in range(num_segments):

                        # calculate start and finish sample for current segment
                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        # extract mfcc
                        # mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        # store only mfcc feature with expected number of vectors
                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/pop/pop.00094.wav, segment:10
#
# Processing: rock
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00002.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00001.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00004.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00003.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00005.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00008.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00000.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00007.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00006.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00013.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00018.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00015.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00019.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00016.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00010.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00012.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00009.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00011.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00014.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00017.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00020.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00030.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00032.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00031.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00028.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00022.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00023.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00033.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00021.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00024.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00027.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00026.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00025.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00029.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00040.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00039.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00044.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00043.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00037.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00036.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00046.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00035.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00041.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00047.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00045.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00042.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00034.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00038.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00051.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00050.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00059.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00055.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00054.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00057.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00057.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00057.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00057.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00057.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/rock/rock.00057.wav, segment:6
# ...
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00071.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00077.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00088.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00090.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00092.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00086.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00085.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00091.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00089.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00087.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00084.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00093.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00096.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00094.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00095.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00098.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00099.wav, segment:10
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:1
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:2
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:3
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:4
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:5
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:6
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:7
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:8
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:9
# /content/drive/MyDrive/GTZAN dataset/Data/genres_original/jazz/jazz.00097.wav, segment:10

# %%
# path to json
DATA_PATH = "/content/drive/MyDrive/GTZAN dataset/data_10.json"

# %%
def load_data(data_path):

    with open(data_path, "r") as f:
        data = json.load(f)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
# load data
X, y = load_data(DATA_PATH)
# Out:
# Data succesfully loaded!

# %%
X.shape
# Out:
# (9986, 130, 13)

# %%
# create train, validation and test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# add an axis to input sets
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
X_train.shape
# Out:
# (7489, 130, 13, 1)

# %%
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# %%
from keras.regularizers import l2
# build the CNN
model_cnn = keras.Sequential()

# 1st conv layer
model_cnn.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model_cnn.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())


# 2nd conv layer
model_cnn.add(keras.layers.Conv2D(64, (3, 3), activation='relu',kernel_initializer='he_uniform',kernel_regularizer=l2(0.0001)))
model_cnn.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Dropout(0.3))

# 3rd conv layer
model_cnn.add(keras.layers.Conv2D(128, (2, 2), activation='relu',kernel_initializer='he_uniform',kernel_regularizer=l2(0.0001)))
model_cnn.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Dropout(0.3))

# flatten output and feed it into dense layer
model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(128, activation='relu',kernel_initializer='he_uniform',kernel_regularizer=l2(0.0001)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Dropout(0.3))

# output layer
model_cnn.add(keras.layers.Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_cnn.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
callbacks = [
             EarlyStopping(patience=3)
]

# %%
model_cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 11, 32)         │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 6, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64, 6, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 62, 4, 64)           │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 31, 2, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 31, 2, 64)           │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 31, 2, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 30, 1, 128)          │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 15, 1, 128)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 15, 1, 128)          │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 15, 1, 128)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1920)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         245,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 300,298 (1.15 MB)
#  Trainable params: 299,594 (1.14 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
# train model
history = model_cnn.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=100,callbacks=callbacks)
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - accuracy: 0.2199 - loss: 2.6892 - val_accuracy: 0.4561 - val_loss: 1.5861
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.3907 - loss: 1.9508 - val_accuracy: 0.5230 - val_loss: 1.4110
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4760 - loss: 1.6297 - val_accuracy: 0.5647 - val_loss: 1.2850
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5068 - loss: 1.4999 - val_accuracy: 0.5963 - val_loss: 1.1961
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5399 - loss: 1.3867 - val_accuracy: 0.6115 - val_loss: 1.1531
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5669 - loss: 1.3248 - val_accuracy: 0.6440 - val_loss: 1.0941
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5861 - loss: 1.2443 - val_accuracy: 0.6636 - val_loss: 1.0373
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6104 - loss: 1.1826 - val_accuracy: 0.6704 - val_loss: 1.0238
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6341 - loss: 1.1232 - val_accuracy: 0.6836 - val_loss: 0.9873
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6314 - loss: 1.1075 - val_accuracy: 0.6844 - val_loss: 0.9728
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6503 - loss: 1.0538 - val_accuracy: 0.6900 - val_loss: 0.9353
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6701 - loss: 0.9894 - val_accuracy: 0.7016 - val_loss: 0.9154
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6793 - loss: 0.9809 - val_accuracy: 0.7052 - val_loss: 0.8919
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6891 - loss: 0.9374 - val_accuracy: 0.7137 - val_loss: 0.8985
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6908 - loss: 0.9445 - val_accuracy: 0.7185 - val_loss: 0.8721
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7203 - loss: 0.8745 - val_accuracy: 0.7165 - val_loss: 0.8967
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7328 - loss: 0.8517 - val_accuracy: 0.7317 - val_loss: 0.8395
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7218 - loss: 0.8279 - val_accuracy: 0.7313 - val_loss: 0.8246
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7298 - loss: 0.8188 - val_accuracy: 0.7113 - val_loss: 0.8622
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7399 - loss: 0.8055 - val_accuracy: 0.7357 - val_loss: 0.8170
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7420 - loss: 0.7958 - val_accuracy: 0.7309 - val_loss: 0.8151
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7552 - loss: 0.7708 - val_accuracy: 0.7457 - val_loss: 0.7999
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7524 - loss: 0.7597 - val_accuracy: 0.7493 - val_loss: 0.7776
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7642 - loss: 0.7292 - val_accuracy: 0.7653 - val_loss: 0.7531
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7795 - loss: 0.7130 - val_accuracy: 0.7481 - val_loss: 0.7782
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7785 - loss: 0.6974 - val_accuracy: 0.7449 - val_loss: 0.7748
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7887 - loss: 0.6773 - val_accuracy: 0.7597 - val_loss: 0.7424
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7943 - loss: 0.6640 - val_accuracy: 0.7513 - val_loss: 0.7701
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7854 - loss: 0.6556 - val_accuracy: 0.7477 - val_loss: 0.7750
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7931 - loss: 0.6532 - val_accuracy: 0.7681 - val_loss: 0.7246
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8017 - loss: 0.6339 - val_accuracy: 0.7573 - val_loss: 0.7668
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8189 - loss: 0.6025 - val_accuracy: 0.7625 - val_loss: 0.7443
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8229 - loss: 0.5927 - val_accuracy: 0.7769 - val_loss: 0.7034
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8153 - loss: 0.5991 - val_accuracy: 0.7645 - val_loss: 0.7261
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8220 - loss: 0.5665 - val_accuracy: 0.7733 - val_loss: 0.7061
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8296 - loss: 0.5682 - val_accuracy: 0.7709 - val_loss: 0.7075

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


# plot accuracy and error as a function of the epochs
plot_history(history)

# %%
import pandas as pd
metrics_df = pd.DataFrame(history.history)
metrics_df.tail(10)
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 26  0.790226  0.678633      0.759712  0.742379
# 27  0.792763  0.663136      0.751302  0.770086
# 28  0.788089  0.661405      0.747697  0.775000
# 29  0.793297  0.657296      0.768122  0.724620
# 30  0.799439  0.637218      0.757309  0.766840
# 31  0.808653  0.620133      0.762515  0.744338
# 32  0.814795  0.607081      0.776932  0.703422
# 33  0.818667  0.585109      0.764517  0.726091
# 34  0.814662  0.586018      0.773328  0.706135
# 35  0.828816  0.566627      0.770925  0.707545

# %%
# evaluate model on Test Set
test_loss, test_acc = model_cnn.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 79/79 - 0s - 2ms/step - accuracy: 0.7709 - loss: 0.7075
#
# Test accuracy: 0.7709251046180725

# %%
model_cnn.save("MusicGenre_CNN.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
new_model = keras.models.load_model("MusicGenre_CNN.h5")
new_model.evaluate(X_test,y_test,batch_size=128)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7705 - loss: 0.7117
# [0.7075450420379639, 0.7709251046180725]

# %% [markdown]
# #**TESTING ON TEST DATASET**

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[100]
y_to_predict = y_test[100]

# %%
X_to_predict.shape
# Out:
# (130, 13, 1)

# %%
# add a dimension to input data for sample - model.predict() expects a 4d array in this case
X_to_predict = X_to_predict[np.newaxis, ...] # array shape (1, 130, 13, 1)

# %%
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
# perform prediction
prediction = model_cnn.predict(X_to_predict)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step

# %%
# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Predicted Genre: 4
# <ipython-input-55-e7146f1bf665>:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Predicted Genre:", int(predicted_index))

# %% [markdown]
# ####**ALL in ONE**

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[50]
y_to_predict = y_test[50]

print("Real Genre:", y_to_predict)

X_to_predict = X_to_predict[np.newaxis, ...]

prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted Genre: 5
# <ipython-input-56-2fa16c5f3e4e>:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Predicted Genre:", int(predicted_index))

# %% [markdown]
# ####**MULTI-TESTING ON TEST DATASET**

# %%
import random
for n in range(10):

  i = random.randint(0,len(X_test))
  # pick a sample to predict from the test set
  X_to_predict = X_test[i]
  y_to_predict = y_test[i]

  print("\nReal Genre:", y_to_predict)

  X_to_predict = X_to_predict[np.newaxis, ...]

  prediction = model_cnn.predict(X_to_predict)

  # get index with max value
  predicted_index = np.argmax(prediction, axis=1)

  print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Genre: 5
#
# Real Genre: 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted Genre: 6
#
# Real Genre: 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Genre: 8
#
# Real Genre: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Genre: 3
#
# Real Genre: 1
# <ipython-input-57-9a538c720ab9>:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Predicted Genre:", int(predicted_index))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted Genre: 1
#
# Real Genre: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Genre: 0
#
# Real Genre: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Genre: 3
#
# Real Genre: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Genre: 1
#
# Real Genre: 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Predicted Genre: 9
#
# Real Genre: 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted Genre: 8
